# %%
###Document Structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is a sample text",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is a sample text')

# %%
## create a simple txt file
import os 
os.makedirs("../data/text_files",exist_ok=True)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Lorem ipsum dolor sit amet, 
    consectetur adipiscing elit. Ut porttitor bibendum quam in luctus. Quisque commodo ipsum vitae dui aliquet posuere. Sed ut imperdiet mi. In non suscipit tellus. Etiam et nibh sem. Aliquam tincidunt accumsan gravida. Cras nec massa pharetra, tristique odio vitae, interdum enim. Cras sed lacinia dolor, sed accumsan tellus.
"""
    }
for file_path, content in sample_texts.items():
    with open(file_path, 'w' ,encoding='utf-8') as f:
        f.write(content)
        print("File written:")
# Out:
# File written:

# %%
### TextLoader 
from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Lorem ipsum dolor sit amet, \n    consectetur adipiscing elit. Ut porttitor bibendum quam in luctus. Quisque commodo ipsum vitae dui aliquet posuere. Sed ut imperdiet mi. In non suscipit tellus. Etiam et nibh sem. Aliquam tincidunt accumsan gravida. Cras nec massa pharetra, tristique odio vitae, interdum enim. Cras sed lacinia dolor, sed accumsan tellus.\n')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

### Load all .txt files in the specified directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)
documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Lorem ipsum dolor sit amet, \n    consectetur adipiscing elit. Ut porttitor bibendum quam in luctus. Quisque commodo ipsum vitae dui aliquet posuere. Sed ut imperdiet mi. In non suscipit tellus. Etiam et nibh sem. Aliquam tincidunt accumsan gravida. Cras nec massa pharetra, tristique odio vitae, interdum enim. Cras sed lacinia dolor, sed accumsan tellus.\n')]
